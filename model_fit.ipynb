# %%
import pandas as pd

# %%
data = pd.read_csv("./OFZ Data - Dataset.csv")
display(data)
# Out:
#       Index  Название Начало Торгов   Погашение  Купон  Периодичность  \
# 0         5     26208    07.03.2012  27.02.2019    7.5              2
# 1        12     26216    13.11.2013  15.05.2019    6.7              2
# 2         7     26210    19.12.2012  11.12.2019    6.8              2
# 3        10     26214    23.10.2013  27.05.2020    6.4              2
# 4         3     26205    13.02.2012  14.04.2021    7.6              2
# ...     ...       ...           ...         ...    ...            ...
# 1538     17     26233    13.05.2020  18.07.2035    6.1              2
# 1539     24     26240    30.06.2021  30.07.2036    7.0              2
# 1540     27     26243    21.06.2023  19.05.2038    9.8              2
# 1541     14     26230    19.06.2019  16.03.2039    7.7              2
# 1542     22     26238    23.06.2021  15.05.2041    7.1              2
#
#               ISIN       start         end      Price  days_to_maturity  \
# ...

# %%
# Out:
# 0
